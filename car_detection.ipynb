# %% [markdown]
# <a href="https://colab.research.google.com/github/rizalanhari/PCVK_Genap_2021/blob/main/car_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
from matplotlib import pyplot as plt
import cv2
import math
from google.colab.patches import cv2_imshow

# %%
parking_lot = cv2.imread('/content/drive/MyDrive/PCVK Project/Car Park/2012-09-21_06_20_11.jpg')
cv2_imshow(parking_lot)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F407ED54E90>

# %%
car_cascade = cv2.CascadeClassifier('/content/drive/MyDrive/PCVK Project/cars6.xml')
parking_lot_2 = cv2.imread('/content/drive/MyDrive/PCVK Project/Car Park/2012-09-21_06_20_11.jpg')

# %%
jumlah =0;
gray = cv2.cvtColor(parking_lot, cv2.COLOR_BGR2GRAY)
cars = car_cascade.detectMultiScale(gray)
for(x,y,w,h) in cars: 
  cv2.rectangle(gray,(x,y),(x+w,y+h),(0,255,0),3) 
  jumlah+=1;
plt.figure(figsize = (10,10)) 

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv2.cvtColor(parking_lot_2, cv2.COLOR_BGR2RGB))
axarr[0].imshow(cv2.cvtColor(parking_lot_2, cv2.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(cv2.cvtColor(gray, cv2.COLOR_BGR2RGB))
axarr[1].imshow(cv2.cvtColor(parking_lot, cv2.COLOR_BGR2RGB))
plt.show()

# %%
print(jumlah)
# Out:
# 19

# %%
gray = cv2.cvtColor(src=parking_lot, code=cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=1280x720 at 0x7F407D077ED0>

# %%
blur_gray = cv2.GaussianBlur(src=gray, ksize=(5, 5), sigmaX=0)
cv2_imshow(blur_gray)
# Out:
# <PIL.Image.Image image mode=L size=1280x720 at 0x7F407CFD5A10>

# %%
img_sobelx = cv2.Sobel(blur_gray, cv2.CV_64F, 1, 0, ksize=3)
img_sobely = cv2.Sobel(blur_gray, cv2.CV_64F, 0, 1, ksize=3)
img_sobelxy = cv2.addWeighted(cv2.convertScaleAbs(img_sobelx), 0.5, cv2.convertScaleAbs(img_sobely), 0.5, 0)

cv2_imshow(img_sobelxy)
# Out:
# <PIL.Image.Image image mode=L size=1280x720 at 0x7F4078AB6790>

# %%
edges = cv2.Canny(img_sobelxy, 50, 150, 3)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=1280x720 at 0x7F4078A669D0>

# %%
jumlah =0;
gray = cv2.cvtColor(parking_lot, cv2.COLOR_BGR2GRAY)
cars = car_cascade.detectMultiScale(gray)
for(x,y,w,h) in cars: 
  cv2.rectangle(th3,(x,y),(x+w,y+h),(0,255,0),3)
  jumlah+=1; 
plt.figure(figsize = (10,10)) 

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv2.cvtColor(th3, cv2.COLOR_BGR2RGB))
axarr[0].imshow(cv2.cvtColor(th3, cv2.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(cv2.cvtColor(th3, cv2.COLOR_BGR2RGB))
axarr[1].imshow(cv2.cvtColor(th3, cv2.COLOR_BGR2RGB))
plt.show()
print(jumlah)
# Out:
# 19
